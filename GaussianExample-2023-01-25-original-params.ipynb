# %%
from __future__ import absolute_import, division, print_function

import numpy as np
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
mpl.rcParams["text.usetex"]=False

# %%
# %matplotlib inline
#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>")

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024)]) #in MB
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# 2023-01-25 16:44:53.575610: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:53.575861: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:53.592389: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:53.592628: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:53.592801: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:53.592966: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
# Define default plot styles  

from matplotlib import rc
import matplotlib.font_manager

rc('font', family='serif')
rc('text', usetex=False)
rc('font', size=22)
rc('xtick', labelsize=15)
rc('ytick', labelsize=15)
rc('legend', fontsize=15)

plot_style_0 = {
    'histtype': 'step',
    'color': 'black',
    'linewidth': 2,
    'linestyle': '--',
    'density': False
}

plot_style_1 = {
    'histtype': 'step',
    'color': 'black',
    'linewidth': 2,
    'density': False
}

plot_style_2 = {'alpha': 0.5, 'density': False}

# %%
# Check Versions
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %% [markdown]
# # OmniFold Gaussian Toy Example

# %% [markdown]
# ## Setup the Datasets

# %%
mu0 = 0
sigma0 = 1

eff = 0.1 #fraction of true but not reco
fake = 0.1 #fraction of reco but not true


##-- original value
back = 0.1 #fraction of a background process that we would like to subtract

#back = 0.2 #fraction of a background process that we would like to subtract
#back = 0.3 #fraction of a background process that we would like to subtract

# %% [markdown]
# ## Owen: learning hyperparameters

# %%
##-- originals

max_epochs = 200
batch_size_setval = 10000
learning_rate_setval = 1e-3
patience_setval = 10

back = 0.1 #fraction of a background process that we would like to subtract
background_param = (0, 1.2)  # background
N = 10**5





##-- more thorough set with more events, higher background, wider background width 

#max_epochs = 200
#batch_size_setval = 1000
#learning_rate_setval = 1e-4
#patience_setval = 40

#back = 0.2 #fraction of a background process that we would like to subtract
#background_param = (0, 3)  # background
#N = 3*10**5

# %%
# %%time




# param = (mu, sigma)
theta0_param = (mu0, sigma0)  # synthetic sample
theta_unknown_param = (0.2, 0.8)  # this is the data (the target)
#background_param = (0, 1.2)  # background
#background_param = (0, 3)  # background
epsilon = sigma0 / 2.  # Smearing width

dummyval = -10 #a value for examples that don't pass one of the measured/ideal selections

#Synthetic
theta0_G = np.random.normal(theta0_param[0], theta0_param[1],N)  # Generator-level synthetic sample
theta0_S = np.array([(x + np.random.normal(0, epsilon)) for x in theta0_G])  # Detector smearing for synthetic sample
pass_reco = np.random.binomial(1,1.-eff,len(theta0_G))
pass_truth = np.random.binomial(1,1.-fake,len(theta0_G)) # what a concise Toy MC with cuts!
theta0_S[pass_reco==0] = dummyval
theta0_G[pass_truth==0] = dummyval

theta0_background = np.random.normal(background_param[0],background_param[1], int(N*back))
theta0_S_withback = np.concatenate([theta0_S,theta0_background]) #smeared synthetic (mc_reco)+background
theta0_G_withback = np.concatenate([theta0_G,-np.ones(int(N*back))*dummyval]) #gen synthetic (mc_truth)+background

theta0 = np.stack([theta0_G, theta0_S], axis=1)
labels0 = np.zeros(len(theta0))

#Natural
theta_unknown_G = np.random.normal(theta_unknown_param[0],theta_unknown_param[1], N) # Nature, particle-level analog
theta_unknown_S = np.array([(x + np.random.normal(0, epsilon)) for x in theta_unknown_G]) # Measured Data analog
pass_reco = np.random.binomial(1,1.-eff,len(theta_unknown_G))
pass_truth = np.random.binomial(1,1.-fake,len(theta_unknown_G))
theta_unknown_S[pass_reco==0] = dummyval
theta_unknown_G[pass_truth==0] = dummyval #emulates cuts done in an analysis

theta_background = np.random.normal(background_param[0],background_param[1], int(N*back))
theta_unknown_S_withback = np.concatenate([theta_unknown_S,theta_background]) #Nature+background
theta_unknown_G_withback = np.concatenate([theta_unknown_G,-np.ones(int(N*back))*dummyval]) #Data+Background

theta_unknown = np.stack([theta_unknown_G, theta_unknown_S], axis=1)
labels_unknown = np.ones(len(theta_unknown))
# Out:
# CPU times: user 508 ms, sys: 0 ns, total: 508 ms
# Wall time: 507 ms

# %%
theta0_G
# Out:
# array([  0.76095756,  -0.47140617,  -0.32675985, ...,   1.39610461,
#          1.81413121, -10.        ])

# %%
theta0_S
# Out:
# array([  0.49623172,  -1.03720578,  -0.76341316, ...,   1.80124784,
#          1.11195419, -10.        ])

# %%
theta0
# Out:
# array([[  0.76095756,   0.49623172],
#        [ -0.47140617,  -1.03720578],
#        [ -0.32675985,  -0.76341316],
#        ...,
#        [  1.39610461,   1.80124784],
#        [  1.81413121,   1.11195419],
#        [-10.        , -10.        ]])

# %%
labels0
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
labels0.shape
# Out:
# (100000,)

# %%
theta0.shape
# Out:
# (100000, 2)

# %%
labels_unknown
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
labels_unknown.shape
# Out:
# (100000,)

# %%
bins = np.linspace(-11, 11, 41)

fig, ax = plt.subplots(1,
                       2,
                       figsize=(12, 5),
                       constrained_layout=True,
                       sharey=True)

ax[0].set_xlabel(r'$x$')
ax[0].set_ylabel(r'Events per bin')
ax[0].hist(theta0_G[theta0_G!=dummyval], bins=bins, **plot_style_2, label='Generation')
ax[0].hist(theta0_S_withback[theta0_S_withback!=dummyval], bins=bins, **plot_style_2, label='Simulation')
ax[0].hist(theta0_S_withback[theta0_G_withback==-dummyval], bins=bins, color="darkorange", label='Background')
legend = ax[0].legend(
    title=r'Synthetic''\n''($\mu$, $\sigma$) = {}'.format(theta0_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[1].set_xlabel(r'$x$')
ax[1].hist(theta_unknown_G[theta_unknown_G!=dummyval], bins=bins, **plot_style_2, label='Truth',color="green")
ax[1].hist(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval], bins=bins, **plot_style_2, label='Data',color="black")
ax[1].hist(theta_unknown_S_withback[theta_unknown_G_withback==-dummyval], bins=bins, label='Background',color="black")
legend = ax[1].legend(
    title=r'Natural''\n''($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

fig.show()
# Out:
# /tmp/ipykernel_2438857/177983796.py:30: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Unfold Data

# %%
iterations = 4

# %%
xvals_1 = np.concatenate((theta0_S, theta_unknown_S)) #synthetic, measured.
yvals_1 = np.concatenate((labels0, labels_unknown)) 
#QUESTION: At what point are theses mixed? Avoid [0,0,0...0,1,1...1,1,1]
#I think at test_train_split function

xvals_2 = np.concatenate((theta0_G, theta0_G)) 
#QUESTION whay 0_G twice? Because theta_unknown_G is ultimate target (particle level – nature), 
#and can't be used as an input to the training.
yvals_2 = np.concatenate((labels0, labels_unknown))

weights = np.empty(shape=(iterations, 2, len(theta0)))
# shape = (iteration, step, event)

inputs = Input((1, ))
hidden_layer_1 = Dense(50, activation='relu')(inputs)
hidden_layer_2 = Dense(50, activation='relu')(hidden_layer_1)
hidden_layer_3 = Dense(50, activation='relu')(hidden_layer_2)
outputs = Dense(1, activation='sigmoid')(hidden_layer_3)

model = Model(inputs=inputs, outputs=outputs)

#earlystopping = EarlyStopping(patience=10,
#                              verbose=1,
#                              restore_best_weights=True)

earlystopping = EarlyStopping(patience=patience_setval,
                              verbose=1,
                              restore_best_weights=True)
# Out:
# 2023-01-25 16:44:54.820278: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:54.820486: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:54.820811: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:54.820977: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:54.821137: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:54.821297: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:55.394181: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:55.394398: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:55.394572: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:55.394736: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:55.394902: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:55.395047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1024 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-01-25 16:44:55.395373: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 16:44:55.395514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22263 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
xvals_1
# Out:
# array([ 0.49623172, -1.03720578, -0.76341316, ...,  0.60319293,
#         0.29238607, -0.76162659])

# %%
xvals_1.shape
# Out:
# (200000,)

# %%
yvals_1
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
yvals_1.shape
# Out:
# (200000,)

# %%
# from NN (DCTR)
def reweight(events):
    f = model.predict(events, batch_size=10000)
    weights = f / (1. - f)
    return np.squeeze(np.nan_to_num(weights)) 
#Question: how is the model passed? Stored in memory before function is called?
#QUESTION: is this p(w,X)/p(w',X'), where p is PDF of (x)?
#reweights sim to data, then

# %%
# %%time

#We can do the background subtraction as part of the iterative unfolding, but it is easier to do it first.


    
x_data_and_MCback = np.concatenate([theta0_S_withback[theta0_G_withback==-dummyval],
                                    theta_unknown_S_withback[theta_unknown_S_withback!=dummyval],
                                    theta_unknown_S_withback[theta_unknown_S_withback!=dummyval]])
    
y_data_and_MCback = np.concatenate([np.ones(len(theta0_S_withback[theta0_G_withback==-dummyval])),
                                    np.ones(len(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval])),
                                    np.zeros(len(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval]))])
    
W_data_and_MCback = np.concatenate([-1.*np.ones(len(theta0_S_withback[theta0_G_withback==-dummyval])),
                                    np.ones(len(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval])),
                                    np.ones(len(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval]))])

X_train_1, X_test_1, Y_train_1, Y_test_1, w_train_1, w_test_1 = train_test_split(
    x_data_and_MCback, y_data_and_MCback, W_data_and_MCback)
# Out:
# CPU times: user 4.36 ms, sys: 4.39 ms, total: 8.74 ms
# Wall time: 8.19 ms

# %% [markdown]
# ## Owen's notes
#
# See my more detailed notes in this file on my laptop: /Users/owen/work/eic/omnifold/2023-01-23-notes.docx
#
# Here's a summary of how the BG subtraction works.
#
# - The NN is given a binary classification task where the two categories are signal-only (y=1, call this a) and signal plus background (y=0, call this b).
#
# - The signal-only sample is constructed by combining the "data" (theta_unknown_S_withback[theta_unknown_S_withback!=dummyval]) with a BG sample (theta0_S_withback[theta0_G_withback==-dummyval]), where the data weight is +1 and the BG weight is -1.  This does the BG subtraction in the loss function because the sum of the BG sample, with weight -1, will cancel the sum of the BG component of the data.
#
# - The NN output f is an estimation of the probability that an event is in the class a and this is approximately a/(a+b).
#
# - The signal fraction is given by a/b.  To get this from f, it's Fr(sig) = f/(1-f) = a/b, which is also the likelihood ratio or the ratio of the probabilities of the two classes.
#
# This BG subtraction trick is to cancel it in the loss function by adding it to the signal+bg sample with a negative weight.

# %%
# %%time

#model.compile(loss='binary_crossentropy',
#              optimizer='Adam',
#              metrics=['accuracy'])

#model.compile(loss='binary_crossentropy',
#              optimizer='Adam',
#              metrics=['accuracy'],
#              weighted_metrics=[])


#training_hist = model.fit(X_train_1,
#          Y_train_1,
#          sample_weight=w_train_1,
#          epochs=200,
#          batch_size=10000,
#          validation_data=(X_test_1, Y_test_1, w_test_1),
#          callbacks=[earlystopping],
#          verbose=1)

the_optimizer = tf.keras.optimizers.Adam( learning_rate=learning_rate_setval )

model.compile(loss='binary_crossentropy',
              optimizer=the_optimizer,
              metrics=['accuracy'],
              weighted_metrics=[])


training_hist = model.fit(X_train_1,
          Y_train_1,
          sample_weight=w_train_1,
          epochs=max_epochs,
          batch_size=batch_size_setval,
          validation_data=(X_test_1, Y_test_1, w_test_1),
          callbacks=[earlystopping],
          verbose=1)
# Out:
# Epoch 1/200
# 2023-01-25 16:45:20.066641: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-01-25 16:45:20.068851: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f7a00477f90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-25 16:45:20.068863: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-01-25 16:45:20.068866: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (1): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-01-25 16:45:20.071993: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-25 16:45:20.153121: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 16/16 [==============================] - 9s 523ms/step - loss: 0.6261 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 2/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6260 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 3/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 4/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 5/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 6/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6254 - val_accuracy: 0.4741
# Epoch 7/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6260 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 8/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 9/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 10/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 11/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6254 - val_accuracy: 0.4741
# Epoch 12/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 13/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6254 - val_accuracy: 0.4741
# Epoch 14/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 15/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 16/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 17/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 18/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 19/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 20/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6254 - val_accuracy: 0.4741
# Epoch 21/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 22/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 23/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 24/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 25/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 26/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 27/200
#  1/16 [>.............................] - ETA: 0s - loss: 0.6274 - accuracy: 0.4782Restoring model weights from the end of the best epoch: 17.
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.4769 - val_loss: 0.6253 - val_accuracy: 0.4741
# Epoch 27: early stopping
# CPU times: user 35 s, sys: 587 ms, total: 35.5 s
# Wall time: 34.4 s

# %%
plt.plot( training_hist.history['loss'])
plt.plot( training_hist.history['val_loss'])

# %%
w_data = reweight(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval])
# Out:
# 11/11 [==============================] - 0s 677us/step

# %%
w_data_bgsub_only = w_data

# %%
i=0
bins = np.linspace(-11, 11, 41)

fig, ax = plt.subplots(1,
                       2,
                       figsize=(12, 5),
                       constrained_layout=True,
                       sharey=True)

ax[0].set_xlabel(r'$x$')
ax[0].set_ylabel('Events per bin')
ax[0].hist(theta0_G[theta0_G!=dummyval], bins=bins, **plot_style_2, label='Generation')
ax[0].hist(theta0_S[theta0_S!=dummyval], bins=bins, **plot_style_2, label='Simulation (no back.)')
legend = ax[0].legend(
    title='Synthetic\n($\mu$, $\sigma$) = {}'.format(theta0_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[1].set_xlabel('$x$')
#ax[1].hist(theta_unknown_G[theta_unknown_G!=dummyval], bins=bins, **plot_style_2, label='Truth',color="green")
ax[1].hist(theta_unknown_S[theta_unknown_S!=dummyval], bins=bins, **plot_style_2, label='Data (no back.)',color="black")
ax[1].hist(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval], bins=bins, histtype="step", label='Data (reweighted)',color="black",weights=w_data)
legend = ax[1].legend(
    title='Natural\n($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

fig.show()
plt.savefig("plot_"+str(i)+"_datareweight.pdf")
# Out:
# /tmp/ipykernel_2438857/236819712.py:30: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
model_output_bgsub = model.predict(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval], batch_size=10000)
# Out:
# 11/11 [==============================] - 0s 672us/step

# %%
model_output_bgsub
# Out:
# array([[0.46497637],
#        [0.47942257],
#        [0.47538665],
#        ...,
#        [0.47833484],
#        [0.47470376],
#        [0.46174926]], dtype=float32)

# %%
model_output_bgsub.shape
# Out:
# (100149, 1)

# %%
squeezed_model_output = np.squeeze(model_output_bgsub)

# %%
squeezed_model_output
# Out:
# array([0.46497637, 0.47942257, 0.47538665, ..., 0.47833484, 0.47470376,
#        0.46174926], dtype=float32)

# %%
squeezed_model_output.shape
# Out:
# (100149,)

# %%
fig,ax = plt.subplots(2,2,figsize=(20,20))



ax[0][0].hist( theta_unknown_S_withback[theta_unknown_S_withback!=dummyval], range=[-10,10], bins=50, alpha=0.8)
ax[0][0].hist( theta_unknown_S[theta_unknown_S!=dummyval], range=[-10,10], bins=50, alpha=0.8)
ax[0][0].hist( theta_background, range=[-10,10], bins=50, histtype="step")

ax[0][1].hist( squeezed_model_output, bins=90 )


ax[1][0].hist2d(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval],
         squeezed_model_output,
         density=True,
         bins=200,
         range=([-10,10],[-0.1,1]),
         norm=mpl.colors.LogNorm())
ax[1][0].grid()

ax[1][1].hist2d(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval],
         w_data,
         density=True,
         bins=200,
         range=([-10,10],[-0.1,1]),
         norm=mpl.colors.LogNorm())
ax[1][1].grid()

plt.show()

# %%
hist_data_all = plt.hist( theta_unknown_S_withback[theta_unknown_S_withback!=dummyval], range=[-10,10], bins=50 )
hist_data_signal = plt.hist( theta_unknown_S[theta_unknown_S!=dummyval], range=[-10,10], bins=50)

# %%
hist_data_all
# Out:
# (array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 9.0000e+00,
#         1.4000e+01, 4.4000e+01, 1.0900e+02, 3.2800e+02, 8.7100e+02,
#         2.1280e+03, 4.2690e+03, 7.7710e+03, 1.1872e+04, 1.5156e+04,
#         1.6380e+04, 1.5056e+04, 1.1421e+04, 7.5770e+03, 4.1040e+03,
#         1.9280e+03, 7.5300e+02, 2.7200e+02, 6.1000e+01, 2.3000e+01,
#         2.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#  array([-10. ,  -9.6,  -9.2,  -8.8,  -8.4,  -8. ,  -7.6,  -7.2,  -6.8,
#          -6.4,  -6. ,  -5.6,  -5.2,  -4.8,  -4.4,  -4. ,  -3.6,  -3.2,
#          -2.8,  -2.4,  -2. ,  -1.6,  -1.2,  -0.8,  -0.4,   0. ,   0.4,
#           0.8,   1.2,   1.6,   2. ,   2.4,   2.8,   3.2,   3.6,   4. ,
#           4.4,   4.8,   5.2,   5.6,   6. ,   6.4,   6.8,   7.2,   7.6,
#           8. ,   8.4,   8.8,   9.2,   9.6,  10. ]),
#  <BarContainer object of 50 artists>)

# %%
hist_data_all[0]
# Out:
# array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 9.0000e+00,
#        1.4000e+01, 4.4000e+01, 1.0900e+02, 3.2800e+02, 8.7100e+02,
#        2.1280e+03, 4.2690e+03, 7.7710e+03, 1.1872e+04, 1.5156e+04,
#        1.6380e+04, 1.5056e+04, 1.1421e+04, 7.5770e+03, 4.1040e+03,
#        1.9280e+03, 7.5300e+02, 2.7200e+02, 6.1000e+01, 2.3000e+01,
#        2.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00])

# %%
hist_axis = hist_data_all[1]

# %%
hist_axis
# Out:
# array([-10. ,  -9.6,  -9.2,  -8.8,  -8.4,  -8. ,  -7.6,  -7.2,  -6.8,
#         -6.4,  -6. ,  -5.6,  -5.2,  -4.8,  -4.4,  -4. ,  -3.6,  -3.2,
#         -2.8,  -2.4,  -2. ,  -1.6,  -1.2,  -0.8,  -0.4,   0. ,   0.4,
#          0.8,   1.2,   1.6,   2. ,   2.4,   2.8,   3.2,   3.6,   4. ,
#          4.4,   4.8,   5.2,   5.6,   6. ,   6.4,   6.8,   7.2,   7.6,
#          8. ,   8.4,   8.8,   9.2,   9.6,  10. ])

# %%
hist_axis_centers = np.ones(50)
for i in range(0,50):
    hist_axis_centers[i] = 0.5*(hist_axis[i]+hist_axis[i+1])
    #print(i, hist_axis_centers[i])

# %%
signal_frac = (hist_data_signal[0])/(hist_data_all[0])
# Out:
# /tmp/ipykernel_2438857/1092752292.py:1: RuntimeWarning: invalid value encountered in true_divide
#   signal_frac = (hist_data_signal[0])/(hist_data_all[0])

# %%
signal_frac
# Out:
# array([       nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan, 0.11111111,
#        0.21428571, 0.27272727, 0.52293578, 0.6097561 , 0.73019518,
#        0.78242481, 0.84352307, 0.87556299, 0.90338612, 0.91462127,
#        0.92295482, 0.92096174, 0.91445583, 0.91434605, 0.90155945,
#        0.85114108, 0.83266932, 0.76102941, 0.6557377 , 0.47826087,
#        0.5       , 0.        ,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan])

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))


ax[0].plot(hist_axis_centers,signal_frac)
ax[0].set_ylim(-0.1,1)
ax[0].set_xlim(-10,10)
ax[0].grid()

ax[1].hist2d(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval],
         w_data_bgsub_only,
         density=True,
         bins=250,
         range=([-10,10],[-0.1,1]),
         norm=mpl.colors.LogNorm())
ax[1].grid()

plt.show()

# %%
of_training_history = np.zeros(shape=(4,2,1000))
of_training_history_val = np.zeros(shape=(4,2,1000))

# %% [markdown]
# ## OmniFold part starts here

# %%
# initial iterative weights are ones
weights_pull = np.ones(len(theta0_S))
weights_push = np.ones(len(theta0_S))

# %%
xvals_1 = np.concatenate((theta0_S, theta_unknown_S_withback[theta_unknown_S_withback!=dummyval]))
yvals_1 = np.concatenate((labels0, np.ones(len(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval]))))

# %%
# %%time

for i in range(iterations):
    print("\n\n\nITERATION: {}\n".format(i + 1))

    
    
    
    
    
    
    # STEP 1: classify Sim. (which is reweighted by weights_push) to Data
    # weights reweighted Sim. --> Data
    print("\n\n\n Iteration %d,  STEP 1, events that pass reco\n\n\n" % (i+1))
    

    weights_1 = np.concatenate((weights_push, w_data))
    #QUESTION: concatenation here confuses me
    # actual weights for Sim., ones for Data (not MC weights)

    X_train_1, X_test_1, Y_train_1, Y_test_1, w_train_1, w_test_1 = train_test_split(
        xvals_1, yvals_1, weights_1) #REMINDER: made up of synthetic+measured

#    model.compile(loss='binary_crossentropy',
#                  optimizer='Adam',
#                  metrics=['accuracy'])

    model.compile(loss='binary_crossentropy',
                  optimizer=the_optimizer,
                  metrics=['accuracy'],
                  weighted_metrics=[])    
    
    this_hist = model.fit(X_train_1[X_train_1!=dummyval],
              Y_train_1[X_train_1!=dummyval],
              sample_weight=w_train_1[X_train_1!=dummyval],
              epochs=max_epochs,
              batch_size=batch_size_setval,
              validation_data=(X_test_1[X_test_1!=dummyval], Y_test_1[X_test_1!=dummyval], w_test_1[X_test_1!=dummyval]),
              callbacks=[earlystopping],
              verbose=1)

    for ei in range(0,len(this_hist.history['loss'])):
        of_training_history[i,0,ei] = this_hist.history['loss'][ei]
        of_training_history_val[i,0,ei] = this_hist.history['val_loss'][ei]
    
    
    weights_pull = weights_push * reweight(theta0_S) 
    #QUESTION: above model used in reweight function (model.predict)?
    #QUESTION: Model trains until synthetic is indistinguishable from data? How does this work? 
    #How are weights then iteratively multiplied?
 







    print("\n\n\n Iteration %d,  STEP 1, events that do NOT pass reco\n\n\n" % (i+1))

    ###
    #Need to do something with events that don't pass reco.
    
    #One option is to take the prior:
    #weights_pull[theta0_S==dummyval] = 1. 
    
    #Another option is to assign the average weight: <w|x_true>.  To do this, we need to estimate this quantity.
    xvals_1b = np.concatenate([theta0_G[theta0_S!=dummyval],theta0_G[theta0_S!=dummyval]])
    yvals_1b = np.concatenate([np.ones(len(theta0_G[theta0_S!=dummyval])),np.zeros(len(theta0_G[theta0_S!=dummyval]))])
    weights_1b = np.concatenate([weights_pull[theta0_S!=dummyval],np.ones(len(theta0_G[theta0_S!=dummyval]))])
    
    X_train_1b, X_test_1b, Y_train_1b, Y_test_1b, w_train_1b, w_test_1b = train_test_split(
        xvals_1b, yvals_1b, weights_1b)    
    
#    model.compile(loss='binary_crossentropy',
#                  optimizer='Adam',
#                  metrics=['accuracy'])
    
    model.compile(loss='binary_crossentropy',
                  optimizer=the_optimizer,
                  metrics=['accuracy'],
                  weighted_metrics=[])
    
    
    this_hist = model.fit(X_train_1b,
              Y_train_1b,
              sample_weight=w_train_1b,
              epochs=max_epochs,
              batch_size=batch_size_setval,
              validation_data=(X_test_1b, Y_test_1b, w_test_1b),
              callbacks=[earlystopping],
              verbose=1)


        
        
        
        
        
        
        
    
    
    
    
    average_vals = reweight(theta0_G[theta0_S==dummyval])
    weights_pull[theta0_S==dummyval] = average_vals
    ###
    
    weights[i, :1, :] = weights_pull
    
    
    
    
    
    
    
    
    
    
    
    
    

    # STEP 2: classify Gen. to reweighted Gen. (which is reweighted by weights_pull)
    # weights Gen. --> reweighted Gen.
    print("\n\n\n Iteration %d,  STEP 2, events that pass reco\n\n\n" % (i+1))

    weights_2 = np.concatenate((np.ones(len(theta0_G)), weights_pull))
    # ones for Gen. (not MC weights), actual weights for (reweighted) Gen.

    X_train_2, X_test_2, Y_train_2, Y_test_2, w_train_2, w_test_2 = train_test_split(
        xvals_2, yvals_2, weights_2)

#    model.compile(loss='binary_crossentropy',
#                  optimizer='Adam',
#                  metrics=['accuracy'])
    

    model.compile(loss='binary_crossentropy',
                  optimizer=the_optimizer,
                  metrics=['accuracy'],
                  weighted_metrics=[])    
    
    this_hist = model.fit(X_train_2,
              Y_train_2,
              sample_weight=w_train_2,
              epochs=max_epochs,
              batch_size=batch_size_setval,
              validation_data=(X_test_2, Y_test_2, w_test_2),
              callbacks=[earlystopping],
              verbose=1)

    for ei in range(0,len(this_hist.history['loss'])):
        of_training_history[i,1,ei] = this_hist.history['loss'][ei]
        of_training_history_val[i,1,ei] = this_hist.history['val_loss'][ei]        
    
    
    
    
    

    
    
    print("\n\n\n Iteration %d,  STEP 2, events that do NOT pass reco\n\n\n" % (i+1))
    
    weights_push = reweight(theta0_G)
    ###
    #Need to do something with events that don't pass truth    
    
    #One option is to take the prior:
    #weights_push[theta0_G==dummyval] = 1. 
    
    #Another option is to assign the average weight: <w|x_reco>.  To do this, we need to estimate this quantity.
    xvals_1b = np.concatenate([theta0_S[theta0_G!=dummyval],theta0_S[theta0_G!=dummyval]])
    yvals_1b = np.concatenate([np.ones(len(theta0_S[theta0_G!=dummyval])),np.zeros(len(theta0_S[theta0_G!=dummyval]))])
    weights_1b = np.concatenate([weights_push[theta0_G!=dummyval],np.ones(len(theta0_S[theta0_G!=dummyval]))])
    
    X_train_1b, X_test_1b, Y_train_1b, Y_test_1b, w_train_1b, w_test_1b = train_test_split(
        xvals_1b, yvals_1b, weights_1b)    
    
    
    
#    model.compile(loss='binary_crossentropy',
#                  optimizer='Adam',
#                  metrics=['accuracy'])
    
    model.compile(loss='binary_crossentropy',
                  optimizer=the_optimizer,
                  metrics=['accuracy'],
                  weighted_metrics=[])    

    
    
    model.fit(X_train_1b,
              Y_train_1b,
              sample_weight=w_train_1b,
              epochs=max_epochs,
              batch_size=batch_size_setval,
              validation_data=(X_test_1b, Y_test_1b, w_test_1b),
              callbacks=[earlystopping],
              verbose=1)
    
    average_vals = reweight(theta0_S[theta0_G==dummyval])
    weights_push[theta0_G==dummyval] = average_vals
    ###    
    
    weights[i, 1:2, :] = weights_push
# Out:
# ITERATION: 1
#
#
#
#
#  Iteration 1,  STEP 1, events that pass reco
#
#
#
# Epoch 1/200
# 15/15 [==============================] - 7s 511ms/step - loss: 0.6505 - accuracy: 0.5167 - val_loss: 0.6463 - val_accuracy: 0.5539
# Epoch 2/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6471 - accuracy: 0.5542 - val_loss: 0.6455 - val_accuracy: 0.5602
# Epoch 3/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6467 - accuracy: 0.5548 - val_loss: 0.6449 - val_accuracy: 0.5606
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6466 - accuracy: 0.5551 - val_loss: 0.6449 - val_accuracy: 0.5578
# Epoch 5/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.5554 - val_loss: 0.6448 - val_accuracy: 0.5589
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6465 - accuracy: 0.5551 - val_loss: 0.6449 - val_accuracy: 0.5603
# Epoch 7/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6465 - accuracy: 0.5551 - val_loss: 0.6448 - val_accuracy: 0.5576
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5544 - val_loss: 0.6448 - val_accuracy: 0.5577
# Epoch 9/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5545 - val_loss: 0.6449 - val_accuracy: 0.5585
# Epoch 10/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6465 - accuracy: 0.5547 - val_loss: 0.6447 - val_accuracy: 0.5596
# Epoch 11/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5553 - val_loss: 0.6447 - val_accuracy: 0.5584
# Epoch 12/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5550 - val_loss: 0.6449 - val_accuracy: 0.5588
# Epoch 13/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5553 - val_loss: 0.6448 - val_accuracy: 0.5585
# Epoch 14/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5545 - val_loss: 0.6448 - val_accuracy: 0.5594
# Epoch 15/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.5551 - val_loss: 0.6449 - val_accuracy: 0.5600
# Epoch 16/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.5553 - val_loss: 0.6448 - val_accuracy: 0.5578
# Epoch 17/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.5553 - val_loss: 0.6447 - val_accuracy: 0.5583
# Epoch 18/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5554 - val_loss: 0.6448 - val_accuracy: 0.5601
# Epoch 19/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5554 - val_loss: 0.6448 - val_accuracy: 0.5580
# Epoch 20/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6463 - accuracy: 0.5559 - val_loss: 0.6447 - val_accuracy: 0.5598
# Epoch 21/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.5562 - val_loss: 0.6448 - val_accuracy: 0.5581
# Epoch 22/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5554 - val_loss: 0.6448 - val_accuracy: 0.5604
# Epoch 23/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.5553 - val_loss: 0.6447 - val_accuracy: 0.5600
# Epoch 24/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5562 - val_loss: 0.6447 - val_accuracy: 0.5587
# Epoch 25/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5550 - val_loss: 0.6447 - val_accuracy: 0.5603
# Epoch 26/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5556 - val_loss: 0.6448 - val_accuracy: 0.5599
# Epoch 27/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6463 - accuracy: 0.5554 - val_loss: 0.6447 - val_accuracy: 0.5605
# Epoch 28/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6463 - accuracy: 0.5555 - val_loss: 0.6447 - val_accuracy: 0.5600
# Epoch 29/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6463 - accuracy: 0.5559 - val_loss: 0.6447 - val_accuracy: 0.5584
# Epoch 30/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6463 - accuracy: 0.5561 - val_loss: 0.6448 - val_accuracy: 0.5587
# Epoch 31/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.5556 - val_loss: 0.6447 - val_accuracy: 0.5589
# Epoch 32/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.5558 - val_loss: 0.6448 - val_accuracy: 0.5599
# Epoch 33/200
#  1/15 [=>............................] - ETA: 0s - loss: 0.6471 - accuracy: 0.5551Restoring model weights from the end of the best epoch: 23.
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6463 - accuracy: 0.5554 - val_loss: 0.6447 - val_accuracy: 0.5598
# Epoch 33: early stopping
# 10/10 [==============================] - 0s 695us/step
#
#
#
#  Iteration 1,  STEP 1, events that do NOT pass reco
#
#
#
# Epoch 1/200
# 14/14 [==============================] - 7s 512ms/step - loss: 0.7557 - accuracy: 0.5002 - val_loss: 0.6930 - val_accuracy: 0.4977
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 0.5007 - val_loss: 0.6908 - val_accuracy: 0.5007
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6898 - accuracy: 0.4995 - val_loss: 0.6890 - val_accuracy: 0.5002
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6885 - accuracy: 0.5002 - val_loss: 0.6877 - val_accuracy: 0.5021
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6877 - accuracy: 0.4991 - val_loss: 0.6871 - val_accuracy: 0.5016
# Epoch 6/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6874 - accuracy: 0.4994 - val_loss: 0.6871 - val_accuracy: 0.5019
# Epoch 7/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6872 - accuracy: 0.4991 - val_loss: 0.6870 - val_accuracy: 0.5023
# Epoch 8/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6871 - accuracy: 0.4983 - val_loss: 0.6865 - val_accuracy: 0.5014
# Epoch 9/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.4984 - val_loss: 0.6866 - val_accuracy: 0.5015
# Epoch 10/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.5004 - val_loss: 0.6868 - val_accuracy: 0.5015
# Epoch 11/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6872 - accuracy: 0.4998 - val_loss: 0.6874 - val_accuracy: 0.5015
# Epoch 12/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.4982 - val_loss: 0.6867 - val_accuracy: 0.5017
# Epoch 13/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6871 - accuracy: 0.4997 - val_loss: 0.6867 - val_accuracy: 0.5017
# Epoch 14/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.4991 - val_loss: 0.6865 - val_accuracy: 0.5021
# Epoch 15/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.5001 - val_loss: 0.6873 - val_accuracy: 0.5014
# Epoch 16/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6872 - accuracy: 0.4989 - val_loss: 0.6866 - val_accuracy: 0.5022
# Epoch 17/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.4996 - val_loss: 0.6864 - val_accuracy: 0.5028
# Epoch 18/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.4985 - val_loss: 0.6864 - val_accuracy: 0.5025
# Epoch 19/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.4998 - val_loss: 0.6864 - val_accuracy: 0.5017
# Epoch 20/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.4992 - val_loss: 0.6864 - val_accuracy: 0.5023
# Epoch 21/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.4993 - val_loss: 0.6865 - val_accuracy: 0.5022
# Epoch 22/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.4989 - val_loss: 0.6866 - val_accuracy: 0.5017
# Epoch 23/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.4991 - val_loss: 0.6866 - val_accuracy: 0.5016
# Epoch 24/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.4988 - val_loss: 0.6864 - val_accuracy: 0.5020
# Epoch 25/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.5000 - val_loss: 0.6865 - val_accuracy: 0.5017
# Epoch 26/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.4994 - val_loss: 0.6864 - val_accuracy: 0.5014
# Epoch 27/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.4998 - val_loss: 0.6865 - val_accuracy: 0.5015
# Epoch 28/200
#  1/14 [=>............................] - ETA: 0s - loss: 0.6859 - accuracy: 0.5034Restoring model weights from the end of the best epoch: 18.
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.4992 - val_loss: 0.6864 - val_accuracy: 0.5015
# Epoch 28: early stopping
# 1/1 [==============================] - 0s 36ms/step
#
#
#
#  Iteration 1,  STEP 2, events that pass reco
#
#
#
# Epoch 1/200
# 15/15 [==============================] - 8s 535ms/step - loss: 0.6867 - accuracy: 0.4998 - val_loss: 0.6858 - val_accuracy: 0.5002
# Epoch 2/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6866 - accuracy: 0.5009 - val_loss: 0.6857 - val_accuracy: 0.4999
# Epoch 3/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5004 - val_loss: 0.6858 - val_accuracy: 0.4999
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.4994 - val_loss: 0.6857 - val_accuracy: 0.5000
# Epoch 5/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6866 - accuracy: 0.4998 - val_loss: 0.6859 - val_accuracy: 0.4991
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5003 - val_loss: 0.6858 - val_accuracy: 0.4993
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5002 - val_loss: 0.6857 - val_accuracy: 0.4997
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5002 - val_loss: 0.6858 - val_accuracy: 0.5005
# Epoch 9/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6866 - accuracy: 0.4995 - val_loss: 0.6858 - val_accuracy: 0.5003
# Epoch 10/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6868 - accuracy: 0.4999 - val_loss: 0.6858 - val_accuracy: 0.4996
# Epoch 11/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.4990 - val_loss: 0.6858 - val_accuracy: 0.4991
# Epoch 12/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5014 - val_loss: 0.6857 - val_accuracy: 0.4998
# Epoch 13/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5005 - val_loss: 0.6861 - val_accuracy: 0.5000
# Epoch 14/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5004 - val_loss: 0.6857 - val_accuracy: 0.5002
# Epoch 15/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5003 - val_loss: 0.6858 - val_accuracy: 0.5003
# Epoch 16/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5000 - val_loss: 0.6858 - val_accuracy: 0.4993
# Epoch 17/200
#  1/15 [=>............................] - ETA: 0s - loss: 0.6882 - accuracy: 0.5008Restoring model weights from the end of the best epoch: 7.
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6868 - accuracy: 0.5007 - val_loss: 0.6858 - val_accuracy: 0.4990
# Epoch 17: early stopping
#
#
#
#  Iteration 1,  STEP 2, events that do NOT pass reco
#
#
#
# 10/10 [==============================] - 0s 683us/step
# Epoch 1/200
# 14/14 [==============================] - 7s 549ms/step - loss: 0.6887 - accuracy: 0.4999 - val_loss: 0.6886 - val_accuracy: 0.5002
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6885 - accuracy: 0.5001 - val_loss: 0.6886 - val_accuracy: 0.5006
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5007 - val_loss: 0.6885 - val_accuracy: 0.5013
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.4998 - val_loss: 0.6886 - val_accuracy: 0.4993
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.4997 - val_loss: 0.6886 - val_accuracy: 0.5001
# Epoch 6/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.4993 - val_loss: 0.6887 - val_accuracy: 0.4990
# Epoch 7/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.4998 - val_loss: 0.6887 - val_accuracy: 0.4993
# Epoch 8/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5005 - val_loss: 0.6887 - val_accuracy: 0.5000
# Epoch 9/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5002 - val_loss: 0.6886 - val_accuracy: 0.4996
# Epoch 10/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5003 - val_loss: 0.6886 - val_accuracy: 0.4988
# Epoch 11/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6884 - accuracy: 0.4996 - val_loss: 0.6886 - val_accuracy: 0.5000
# Epoch 12/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6885 - accuracy: 0.4987 - val_loss: 0.6888 - val_accuracy: 0.4998
# Epoch 13/200
#  1/14 [=>............................] - ETA: 0s - loss: 0.6891 - accuracy: 0.4929Restoring model weights from the end of the best epoch: 3.
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.4994 - val_loss: 0.6889 - val_accuracy: 0.4988
# Epoch 13: early stopping
# 1/1 [==============================] - 0s 36ms/step
#
#
#
# ITERATION: 2
#
#
#
#
#  Iteration 2,  STEP 1, events that pass reco
#
#
#
# Epoch 1/200
# 15/15 [==============================] - 8s 556ms/step - loss: 0.6555 - accuracy: 0.5532 - val_loss: 0.6558 - val_accuracy: 0.5425
# Epoch 2/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6553 - accuracy: 0.5460 - val_loss: 0.6558 - val_accuracy: 0.5477
# Epoch 3/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6552 - accuracy: 0.5535 - val_loss: 0.6557 - val_accuracy: 0.5514
# Epoch 4/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6551 - accuracy: 0.5542 - val_loss: 0.6558 - val_accuracy: 0.5505
# Epoch 5/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6551 - accuracy: 0.5539 - val_loss: 0.6557 - val_accuracy: 0.5529
# Epoch 6/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6551 - accuracy: 0.5554 - val_loss: 0.6558 - val_accuracy: 0.5554
# Epoch 7/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6551 - accuracy: 0.5477 - val_loss: 0.6559 - val_accuracy: 0.5558
# Epoch 8/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6552 - accuracy: 0.5555 - val_loss: 0.6558 - val_accuracy: 0.5508
# Epoch 9/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6551 - accuracy: 0.5505 - val_loss: 0.6558 - val_accuracy: 0.5534
# Epoch 10/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6551 - accuracy: 0.5546 - val_loss: 0.6559 - val_accuracy: 0.5566
# Epoch 11/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6552 - accuracy: 0.5486 - val_loss: 0.6559 - val_accuracy: 0.5569
# Epoch 12/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6552 - accuracy: 0.5551 - val_loss: 0.6558 - val_accuracy: 0.5459
# Epoch 13/200
#  1/15 [=>............................] - ETA: 0s - loss: 0.6539 - accuracy: 0.5500Restoring model weights from the end of the best epoch: 3.
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6551 - accuracy: 0.5553 - val_loss: 0.6558 - val_accuracy: 0.5508
# Epoch 13: early stopping
# 10/10 [==============================] - 0s 690us/step
#
#
#
#  Iteration 2,  STEP 1, events that do NOT pass reco
#
#
#
# Epoch 1/200
# 14/14 [==============================] - 7s 525ms/step - loss: 0.6838 - accuracy: 0.5001 - val_loss: 0.6825 - val_accuracy: 0.4984
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.5004 - val_loss: 0.6815 - val_accuracy: 0.5022
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6809 - accuracy: 0.5004 - val_loss: 0.6816 - val_accuracy: 0.5009
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6808 - accuracy: 0.5004 - val_loss: 0.6821 - val_accuracy: 0.4979
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5008 - val_loss: 0.6814 - val_accuracy: 0.5007
# Epoch 6/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.5012 - val_loss: 0.6814 - val_accuracy: 0.5025
# Epoch 7/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.5006 - val_loss: 0.6814 - val_accuracy: 0.5008
# Epoch 8/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.5002 - val_loss: 0.6818 - val_accuracy: 0.4970
# Epoch 9/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5008 - val_loss: 0.6813 - val_accuracy: 0.5005
# Epoch 10/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5003 - val_loss: 0.6813 - val_accuracy: 0.5009
# Epoch 11/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5007 - val_loss: 0.6814 - val_accuracy: 0.4969
# Epoch 12/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.5007 - val_loss: 0.6815 - val_accuracy: 0.4965
# Epoch 13/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5009 - val_loss: 0.6813 - val_accuracy: 0.5006
# Epoch 14/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5005 - val_loss: 0.6813 - val_accuracy: 0.5008
# Epoch 15/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6808 - accuracy: 0.5006 - val_loss: 0.6814 - val_accuracy: 0.4968
# Epoch 16/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5008 - val_loss: 0.6818 - val_accuracy: 0.4989
# Epoch 17/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6807 - accuracy: 0.5006 - val_loss: 0.6814 - val_accuracy: 0.4969
# Epoch 18/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5004 - val_loss: 0.6818 - val_accuracy: 0.4967
# Epoch 19/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5004 - val_loss: 0.6813 - val_accuracy: 0.5007
# Epoch 20/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.4993 - val_loss: 0.6814 - val_accuracy: 0.4966
# Epoch 21/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5011 - val_loss: 0.6816 - val_accuracy: 0.4981
# Epoch 22/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5006 - val_loss: 0.6815 - val_accuracy: 0.4969
# Epoch 23/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5003 - val_loss: 0.6813 - val_accuracy: 0.5005
# Epoch 24/200
#  1/14 [=>............................] - ETA: 0s - loss: 0.6832 - accuracy: 0.5041Restoring model weights from the end of the best epoch: 14.
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5004 - val_loss: 0.6813 - val_accuracy: 0.5006
# Epoch 24: early stopping
# 1/1 [==============================] - 0s 37ms/step
#
#
#
#  Iteration 2,  STEP 2, events that pass reco
#
#
#
# Epoch 1/200
# 15/15 [==============================] - 8s 541ms/step - loss: 0.6804 - accuracy: 0.5005 - val_loss: 0.6803 - val_accuracy: 0.5017
# Epoch 2/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.4998 - val_loss: 0.6806 - val_accuracy: 0.4990
# Epoch 3/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6805 - accuracy: 0.5001 - val_loss: 0.6802 - val_accuracy: 0.4999
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.4997 - val_loss: 0.6802 - val_accuracy: 0.5013
# Epoch 5/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.5006 - val_loss: 0.6801 - val_accuracy: 0.5018
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.4991 - val_loss: 0.6801 - val_accuracy: 0.5018
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.4999 - val_loss: 0.6802 - val_accuracy: 0.5021
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6805 - accuracy: 0.4997 - val_loss: 0.6806 - val_accuracy: 0.4992
# Epoch 9/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6805 - accuracy: 0.4987 - val_loss: 0.6801 - val_accuracy: 0.5016
# Epoch 10/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.5002 - val_loss: 0.6802 - val_accuracy: 0.5012
# Epoch 11/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.4997 - val_loss: 0.6806 - val_accuracy: 0.4987
# Epoch 12/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6805 - accuracy: 0.4996 - val_loss: 0.6803 - val_accuracy: 0.4990
# Epoch 13/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.4991 - val_loss: 0.6802 - val_accuracy: 0.5012
# Epoch 14/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.5002 - val_loss: 0.6801 - val_accuracy: 0.5024
# Epoch 15/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.5003 - val_loss: 0.6802 - val_accuracy: 0.5016
# Epoch 16/200
#  1/15 [=>............................] - ETA: 0s - loss: 0.6803 - accuracy: 0.5056Restoring model weights from the end of the best epoch: 6.
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.5002 - val_loss: 0.6802 - val_accuracy: 0.4991
# Epoch 16: early stopping
#
#
#
#  Iteration 2,  STEP 2, events that do NOT pass reco
#
#
#
# 10/10 [==============================] - 0s 612us/step
# Epoch 1/200
# 14/14 [==============================] - 7s 546ms/step - loss: 0.6837 - accuracy: 0.4993 - val_loss: 0.6826 - val_accuracy: 0.5036
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.4987 - val_loss: 0.6829 - val_accuracy: 0.5042
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.4984 - val_loss: 0.6827 - val_accuracy: 0.5040
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.4988 - val_loss: 0.6827 - val_accuracy: 0.5038
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.4986 - val_loss: 0.6827 - val_accuracy: 0.5038
# Epoch 6/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6828 - accuracy: 0.4989 - val_loss: 0.6828 - val_accuracy: 0.5033
# Epoch 7/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6829 - accuracy: 0.4987 - val_loss: 0.6827 - val_accuracy: 0.5041
# Epoch 8/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6829 - accuracy: 0.4990 - val_loss: 0.6827 - val_accuracy: 0.5039
# Epoch 9/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6829 - accuracy: 0.4978 - val_loss: 0.6827 - val_accuracy: 0.5036
# Epoch 10/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6829 - accuracy: 0.4992 - val_loss: 0.6827 - val_accuracy: 0.5035
# Epoch 11/200
#  1/14 [=>............................] - ETA: 0s - loss: 0.6814 - accuracy: 0.4951Restoring model weights from the end of the best epoch: 1.
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6829 - accuracy: 0.4993 - val_loss: 0.6827 - val_accuracy: 0.5033
# Epoch 11: early stopping
# 1/1 [==============================] - 0s 37ms/step
#
#
#
# ITERATION: 3
#
#
#
#
#  Iteration 3,  STEP 1, events that pass reco
#
#
#
# Epoch 1/200
# 15/15 [==============================] - 8s 538ms/step - loss: 0.6554 - accuracy: 0.5529 - val_loss: 0.6539 - val_accuracy: 0.5438
# Epoch 2/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6537 - accuracy: 0.5486 - val_loss: 0.6538 - val_accuracy: 0.5524
# Epoch 3/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6537 - accuracy: 0.5432 - val_loss: 0.6537 - val_accuracy: 0.5276
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6537 - accuracy: 0.5452 - val_loss: 0.6538 - val_accuracy: 0.5208
# Epoch 5/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6537 - accuracy: 0.5462 - val_loss: 0.6537 - val_accuracy: 0.5554
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6536 - accuracy: 0.5524 - val_loss: 0.6537 - val_accuracy: 0.5554
# Epoch 7/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5545 - val_loss: 0.6537 - val_accuracy: 0.5520
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6537 - accuracy: 0.5450 - val_loss: 0.6537 - val_accuracy: 0.5375
# Epoch 9/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5475 - val_loss: 0.6538 - val_accuracy: 0.5573
# Epoch 10/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5545 - val_loss: 0.6537 - val_accuracy: 0.5518
# Epoch 11/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6537 - accuracy: 0.5437 - val_loss: 0.6538 - val_accuracy: 0.5530
# Epoch 12/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5507 - val_loss: 0.6537 - val_accuracy: 0.5544
# Epoch 13/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6537 - accuracy: 0.5516 - val_loss: 0.6538 - val_accuracy: 0.5190
# Epoch 14/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6537 - accuracy: 0.5458 - val_loss: 0.6537 - val_accuracy: 0.5467
# Epoch 15/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5468 - val_loss: 0.6538 - val_accuracy: 0.5524
# Epoch 16/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5530 - val_loss: 0.6537 - val_accuracy: 0.5539
# Epoch 17/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5494 - val_loss: 0.6537 - val_accuracy: 0.5531
# Epoch 18/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5573 - val_loss: 0.6537 - val_accuracy: 0.5572
# Epoch 19/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5497 - val_loss: 0.6538 - val_accuracy: 0.5509
# Epoch 20/200
#  1/15 [=>............................] - ETA: 0s - loss: 0.6509 - accuracy: 0.5625Restoring model weights from the end of the best epoch: 10.
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5531 - val_loss: 0.6537 - val_accuracy: 0.5501
# Epoch 20: early stopping
# 10/10 [==============================] - 0s 639us/step
#
#
#
#  Iteration 3,  STEP 1, events that do NOT pass reco
#
#
#
# Epoch 1/200
# 14/14 [==============================] - 7s 551ms/step - loss: 0.6874 - accuracy: 0.4997 - val_loss: 0.6837 - val_accuracy: 0.4992
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.5005 - val_loss: 0.6802 - val_accuracy: 0.5005
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6796 - accuracy: 0.5003 - val_loss: 0.6806 - val_accuracy: 0.4999
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6794 - accuracy: 0.5006 - val_loss: 0.6800 - val_accuracy: 0.4994
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6793 - accuracy: 0.4999 - val_loss: 0.6801 - val_accuracy: 0.4995
# Epoch 6/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6793 - accuracy: 0.4993 - val_loss: 0.6800 - val_accuracy: 0.4997
# Epoch 7/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6793 - accuracy: 0.5004 - val_loss: 0.6802 - val_accuracy: 0.4997
# Epoch 8/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6793 - accuracy: 0.5005 - val_loss: 0.6800 - val_accuracy: 0.4991
# Epoch 9/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.5002 - val_loss: 0.6800 - val_accuracy: 0.4991
# Epoch 10/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.4997 - val_loss: 0.6800 - val_accuracy: 0.4996
# Epoch 11/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.4995 - val_loss: 0.6800 - val_accuracy: 0.4996
# Epoch 12/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.4996 - val_loss: 0.6800 - val_accuracy: 0.4992
# Epoch 13/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6793 - accuracy: 0.5000 - val_loss: 0.6801 - val_accuracy: 0.4989
# Epoch 14/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.5003 - val_loss: 0.6802 - val_accuracy: 0.4995
# Epoch 15/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.5002 - val_loss: 0.6800 - val_accuracy: 0.4997
# Epoch 16/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.4991 - val_loss: 0.6800 - val_accuracy: 0.5000
# Epoch 17/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6792 - accuracy: 0.4994 - val_loss: 0.6800 - val_accuracy: 0.4992
# Epoch 18/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6791 - accuracy: 0.4999 - val_loss: 0.6800 - val_accuracy: 0.4989
# Epoch 19/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.5001 - val_loss: 0.6802 - val_accuracy: 0.4997
# Epoch 20/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.5002 - val_loss: 0.6800 - val_accuracy: 0.4993
# Epoch 21/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.5004 - val_loss: 0.6802 - val_accuracy: 0.4994
# Epoch 22/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.5002 - val_loss: 0.6801 - val_accuracy: 0.4999
# Epoch 23/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6793 - accuracy: 0.4994 - val_loss: 0.6801 - val_accuracy: 0.5003
# Epoch 24/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.4998 - val_loss: 0.6800 - val_accuracy: 0.4990
# Epoch 25/200
#  1/14 [=>............................] - ETA: 0s - loss: 0.6793 - accuracy: 0.4987Restoring model weights from the end of the best epoch: 15.
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.4998 - val_loss: 0.6801 - val_accuracy: 0.4995
# Epoch 25: early stopping
# 1/1 [==============================] - 0s 38ms/step
#
#
#
#  Iteration 3,  STEP 2, events that pass reco
#
#
#
# Epoch 1/200
# 15/15 [==============================] - 8s 568ms/step - loss: 0.6800 - accuracy: 0.5017 - val_loss: 0.6796 - val_accuracy: 0.4956
# Epoch 2/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5015 - val_loss: 0.6798 - val_accuracy: 0.4963
# Epoch 3/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5010 - val_loss: 0.6793 - val_accuracy: 0.4956
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5014 - val_loss: 0.6793 - val_accuracy: 0.4965
# Epoch 5/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5013 - val_loss: 0.6793 - val_accuracy: 0.4965
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5020 - val_loss: 0.6793 - val_accuracy: 0.4959
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5017 - val_loss: 0.6794 - val_accuracy: 0.4960
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5006 - val_loss: 0.6793 - val_accuracy: 0.4950
# Epoch 9/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5016 - val_loss: 0.6794 - val_accuracy: 0.4949
# Epoch 10/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5013 - val_loss: 0.6794 - val_accuracy: 0.4956
# Epoch 11/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5010 - val_loss: 0.6795 - val_accuracy: 0.4951
# Epoch 12/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5011 - val_loss: 0.6794 - val_accuracy: 0.4949
# Epoch 13/200
#  1/15 [=>............................] - ETA: 0s - loss: 0.6794 - accuracy: 0.5058Restoring model weights from the end of the best epoch: 3.
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5017 - val_loss: 0.6793 - val_accuracy: 0.4965
# Epoch 13: early stopping
#
#
#
#  Iteration 3,  STEP 2, events that do NOT pass reco
#
#
#
# 10/10 [==============================] - 0s 591us/step
# Epoch 1/200
# 14/14 [==============================] - 8s 568ms/step - loss: 0.6813 - accuracy: 0.4990 - val_loss: 0.6805 - val_accuracy: 0.5004
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.5007 - val_loss: 0.6806 - val_accuracy: 0.5002
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.4990 - val_loss: 0.6805 - val_accuracy: 0.5005
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.4989 - val_loss: 0.6806 - val_accuracy: 0.4990
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.5002 - val_loss: 0.6805 - val_accuracy: 0.5007
# Epoch 6/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.5001 - val_loss: 0.6804 - val_accuracy: 0.5000
# Epoch 7/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4997 - val_loss: 0.6805 - val_accuracy: 0.4994
# Epoch 8/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4996 - val_loss: 0.6805 - val_accuracy: 0.4990
# Epoch 9/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4997 - val_loss: 0.6805 - val_accuracy: 0.4987
# Epoch 10/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6802 - accuracy: 0.5001 - val_loss: 0.6804 - val_accuracy: 0.5008
# Epoch 11/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4994 - val_loss: 0.6806 - val_accuracy: 0.4990
# Epoch 12/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5000 - val_loss: 0.6804 - val_accuracy: 0.5003
# Epoch 13/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.4999 - val_loss: 0.6805 - val_accuracy: 0.5008
# Epoch 14/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6803 - accuracy: 0.4997 - val_loss: 0.6804 - val_accuracy: 0.5006
# Epoch 15/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4991 - val_loss: 0.6806 - val_accuracy: 0.4998
# Epoch 16/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6803 - accuracy: 0.5004 - val_loss: 0.6805 - val_accuracy: 0.5000
# Epoch 17/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6802 - accuracy: 0.5007 - val_loss: 0.6805 - val_accuracy: 0.5008
# Epoch 18/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4998 - val_loss: 0.6805 - val_accuracy: 0.5007
# Epoch 19/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4998 - val_loss: 0.6805 - val_accuracy: 0.4995
# Epoch 20/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.5002 - val_loss: 0.6804 - val_accuracy: 0.5004
# Epoch 21/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6803 - accuracy: 0.4990 - val_loss: 0.6805 - val_accuracy: 0.5008
# Epoch 22/200
#  1/14 [=>............................] - ETA: 0s - loss: 0.6818 - accuracy: 0.4980Restoring model weights from the end of the best epoch: 12.
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4998 - val_loss: 0.6805 - val_accuracy: 0.5006
# Epoch 22: early stopping
# 1/1 [==============================] - 0s 36ms/step
#
#
#
# ITERATION: 4
#
#
#
#
#  Iteration 4,  STEP 1, events that pass reco
#
#
#
# Epoch 1/200
# 15/15 [==============================] - 8s 527ms/step - loss: 0.6556 - accuracy: 0.5532 - val_loss: 0.6533 - val_accuracy: 0.5434
# Epoch 2/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6529 - accuracy: 0.5377 - val_loss: 0.6522 - val_accuracy: 0.5486
# Epoch 3/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6526 - accuracy: 0.5408 - val_loss: 0.6521 - val_accuracy: 0.5529
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6525 - accuracy: 0.5556 - val_loss: 0.6521 - val_accuracy: 0.5588
# Epoch 5/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5564 - val_loss: 0.6521 - val_accuracy: 0.5556
# Epoch 6/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5548 - val_loss: 0.6521 - val_accuracy: 0.5585
# Epoch 7/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5575 - val_loss: 0.6521 - val_accuracy: 0.5591
# Epoch 8/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5529 - val_loss: 0.6521 - val_accuracy: 0.5589
# Epoch 9/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5208 - val_loss: 0.6521 - val_accuracy: 0.5392
# Epoch 10/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5479 - val_loss: 0.6522 - val_accuracy: 0.5434
# Epoch 11/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5558 - val_loss: 0.6521 - val_accuracy: 0.5581
# Epoch 12/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6525 - accuracy: 0.5555 - val_loss: 0.6521 - val_accuracy: 0.5552
# Epoch 13/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5572 - val_loss: 0.6521 - val_accuracy: 0.5598
# Epoch 14/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5560 - val_loss: 0.6521 - val_accuracy: 0.5575
# Epoch 15/200
#  1/15 [=>............................] - ETA: 0s - loss: 0.6506 - accuracy: 0.5590Restoring model weights from the end of the best epoch: 5.
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.5579 - val_loss: 0.6521 - val_accuracy: 0.5589
# Epoch 15: early stopping
# 10/10 [==============================] - 0s 655us/step
#
#
#
#  Iteration 4,  STEP 1, events that do NOT pass reco
#
#
#
# Epoch 1/200
# 14/14 [==============================] - 7s 538ms/step - loss: 0.6893 - accuracy: 0.5003 - val_loss: 0.6849 - val_accuracy: 0.5001
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6831 - accuracy: 0.4993 - val_loss: 0.6812 - val_accuracy: 0.5004
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.4993 - val_loss: 0.6803 - val_accuracy: 0.4971
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6798 - accuracy: 0.5000 - val_loss: 0.6801 - val_accuracy: 0.5006
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6797 - accuracy: 0.5001 - val_loss: 0.6801 - val_accuracy: 0.4999
# Epoch 6/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6796 - accuracy: 0.5002 - val_loss: 0.6797 - val_accuracy: 0.4988
# Epoch 7/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5009 - val_loss: 0.6797 - val_accuracy: 0.5001
# Epoch 8/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5012 - val_loss: 0.6796 - val_accuracy: 0.4992
# Epoch 9/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6794 - accuracy: 0.4998 - val_loss: 0.6797 - val_accuracy: 0.5001
# Epoch 10/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6794 - accuracy: 0.5005 - val_loss: 0.6797 - val_accuracy: 0.4982
# Epoch 11/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.4995 - val_loss: 0.6797 - val_accuracy: 0.4986
# Epoch 12/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5001 - val_loss: 0.6797 - val_accuracy: 0.4999
# Epoch 13/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5000 - val_loss: 0.6796 - val_accuracy: 0.4999
# Epoch 14/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6796 - accuracy: 0.5006 - val_loss: 0.6798 - val_accuracy: 0.5009
# Epoch 15/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6796 - accuracy: 0.4997 - val_loss: 0.6797 - val_accuracy: 0.5000
# Epoch 16/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5004 - val_loss: 0.6797 - val_accuracy: 0.4997
# Epoch 17/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6794 - accuracy: 0.5007 - val_loss: 0.6797 - val_accuracy: 0.4984
# Epoch 18/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5001 - val_loss: 0.6798 - val_accuracy: 0.4985
# Epoch 19/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.4998 - val_loss: 0.6799 - val_accuracy: 0.4983
# Epoch 20/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.4995 - val_loss: 0.6797 - val_accuracy: 0.4983
# Epoch 21/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5003 - val_loss: 0.6797 - val_accuracy: 0.4997
# Epoch 22/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5003 - val_loss: 0.6796 - val_accuracy: 0.4998
# Epoch 23/200
#  1/14 [=>............................] - ETA: 0s - loss: 0.6778 - accuracy: 0.5042Restoring model weights from the end of the best epoch: 13.
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.4997 - val_loss: 0.6797 - val_accuracy: 0.4995
# Epoch 23: early stopping
# 1/1 [==============================] - 0s 37ms/step
#
#
#
#  Iteration 4,  STEP 2, events that pass reco
#
#
#
# Epoch 1/200
# 15/15 [==============================] - 8s 539ms/step - loss: 0.6799 - accuracy: 0.4979 - val_loss: 0.6795 - val_accuracy: 0.5020
# Epoch 2/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.4984 - val_loss: 0.6796 - val_accuracy: 0.5034
# Epoch 3/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6799 - accuracy: 0.4986 - val_loss: 0.6794 - val_accuracy: 0.5053
# Epoch 4/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6798 - accuracy: 0.4986 - val_loss: 0.6794 - val_accuracy: 0.5049
# Epoch 5/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4989 - val_loss: 0.6794 - val_accuracy: 0.5045
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4989 - val_loss: 0.6794 - val_accuracy: 0.5022
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4987 - val_loss: 0.6795 - val_accuracy: 0.5022
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4990 - val_loss: 0.6793 - val_accuracy: 0.5048
# Epoch 9/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4978 - val_loss: 0.6795 - val_accuracy: 0.5024
# Epoch 10/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.4985 - val_loss: 0.6794 - val_accuracy: 0.5047
# Epoch 11/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.4986 - val_loss: 0.6795 - val_accuracy: 0.5030
# Epoch 12/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.4988 - val_loss: 0.6795 - val_accuracy: 0.5023
# Epoch 13/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4984 - val_loss: 0.6794 - val_accuracy: 0.5048
# Epoch 14/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.4988 - val_loss: 0.6794 - val_accuracy: 0.5048
# Epoch 15/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4996 - val_loss: 0.6794 - val_accuracy: 0.5050
# Epoch 16/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4991 - val_loss: 0.6795 - val_accuracy: 0.5022
# Epoch 17/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4984 - val_loss: 0.6794 - val_accuracy: 0.5050
# Epoch 18/200
#  1/15 [=>............................] - ETA: 0s - loss: 0.6825 - accuracy: 0.4943Restoring model weights from the end of the best epoch: 8.
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4981 - val_loss: 0.6794 - val_accuracy: 0.5051
# Epoch 18: early stopping
#
#
#
#  Iteration 4,  STEP 2, events that do NOT pass reco
#
#
#
# 10/10 [==============================] - 0s 698us/step
# Epoch 1/200
# 14/14 [==============================] - 8s 559ms/step - loss: 0.6868 - accuracy: 0.5000 - val_loss: 0.6872 - val_accuracy: 0.4994
# Epoch 2/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6860 - accuracy: 0.5008 - val_loss: 0.6871 - val_accuracy: 0.5005
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6859 - accuracy: 0.5003 - val_loss: 0.6871 - val_accuracy: 0.4987
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.5004 - val_loss: 0.6871 - val_accuracy: 0.4995
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.4996 - val_loss: 0.6870 - val_accuracy: 0.4995
# Epoch 6/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6858 - accuracy: 0.4997 - val_loss: 0.6872 - val_accuracy: 0.4988
# Epoch 7/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6857 - accuracy: 0.5003 - val_loss: 0.6870 - val_accuracy: 0.4988
# Epoch 8/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6857 - accuracy: 0.5006 - val_loss: 0.6872 - val_accuracy: 0.4991
# Epoch 9/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.5001 - val_loss: 0.6871 - val_accuracy: 0.4986
# Epoch 10/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.4998 - val_loss: 0.6871 - val_accuracy: 0.4994
# Epoch 11/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.4996 - val_loss: 0.6872 - val_accuracy: 0.4997
# Epoch 12/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6857 - accuracy: 0.4996 - val_loss: 0.6871 - val_accuracy: 0.4996
# Epoch 13/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.4993 - val_loss: 0.6872 - val_accuracy: 0.4992
# Epoch 14/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.5002 - val_loss: 0.6870 - val_accuracy: 0.4997
# Epoch 15/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6857 - accuracy: 0.5001 - val_loss: 0.6872 - val_accuracy: 0.4987
# Epoch 16/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6857 - accuracy: 0.5008 - val_loss: 0.6871 - val_accuracy: 0.4999
# Epoch 17/200
#  1/14 [=>............................] - ETA: 0s - loss: 0.6835 - accuracy: 0.5009Restoring model weights from the end of the best epoch: 7.
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6857 - accuracy: 0.4996 - val_loss: 0.6871 - val_accuracy: 0.4999
# Epoch 17: early stopping
# 1/1 [==============================] - 0s 41ms/step
# CPU times: user 8min 21s, sys: 4.31 s, total: 8min 26s
# Wall time: 8min 12s

# %%
bins = np.linspace(-4, 4, 41)

plt.figure(figsize=(12, 5))

fig, ax = plt.subplots(1,
                       2,
                       figsize=(12, 6),
                       constrained_layout=True,
                       sharey=True)

#Detector-level
ax[0].set_title("Initialization, Detector-level",style='italic',loc='right')
hist0 = ax[0].hist(theta0_S[theta0_S!=dummyval],
                 bins=bins,
                 color="orange",
                 label=r'($\mu$, $\sigma$) = {}'.format(theta0_param),
                 **plot_style_2)

_,_,_= ax[0].hist(
    theta0_S[theta0_S!=0],
    bins=bins,
    label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),
    **plot_style_1)
_,_,_= ax[0].hist(theta_unknown_S[theta_unknown_S!=dummyval],
                 bins=bins,
                 label=r'($\mu$, $\sigma$) = ?',
                 weights=weights[i, 0, :][theta_unknown_S!=dummyval],
                 **plot_style_2,
                color="black")
ax[0].legend(frameon=False)
ax[0].set_xlabel(r"$x_S$")
ax[0].set_ylabel("Events per bin")

#Particle-level
ax[1].set_title("Initialization, Particle-level",style='italic',loc='right')
_,_,_=ax[1].hist(theta0_G[theta0_G!=dummyval],
                 bins=bins,
                 label=r'($\mu$, $\sigma$) = {}'.format(theta0_param),
                 **plot_style_2)

_,_,_= ax[1].hist(
    theta0_G[theta0_G!=0],
    bins=bins,
    label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),
    **plot_style_1)
_,_,_= ax[1].hist(theta_unknown_G[theta_unknown_G!=dummyval],
                 bins=bins,
                 label=r'($\mu$, $\sigma$) = ?',
                 **plot_style_2,
                color="green")
ax[1].legend(frameon=False)
ax[1].set_xlabel(r"$x_G$")
ax[1].set_ylabel("Events per bin")

plt.savefig("plot_0.pdf")

#Iterations
for i in range(iterations):
    print("ITERATION {}:".format(i + 1))
    plt.figure(figsize=(12, 5))
    
    fig, ax = plt.subplots(1,2,
                       figsize=(12, 6),
                       constrained_layout=True,
                       sharey=True)
    
    #Detector-level
    ax[0].set_title("Iteration " +str(i+1)+ ", Step 1",style='italic',loc='right')
    _,_,_ = ax[0].hist(theta0_S[theta0_S!=dummyval],
                     bins=bins,
                     label=r'($\mu$, $\sigma$) = {}'.format(theta0_param),
                     color="orange",
                     **plot_style_2)

    _,_,_ = ax[0].hist(
        theta0_S[theta0_S!=dummyval],
        bins=bins,
        label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),
        weights=weights[i, 0, :][theta0_S!=dummyval],
        **plot_style_1)
    _,_,_ = ax[0].hist(theta_unknown_S[theta_unknown_S!=dummyval],
                     bins=bins,
                     label=r'($\mu$, $\sigma$) = ?',
                     **plot_style_2,
                    color="black")
    ax[0].legend(frameon=False)
    ax[0].set_xlabel(r"$x_S$")
    ax[0].set_ylabel("Events per bin")
    
    #Particle-level
    ax[1].set_title("Iteration " +str(i+1)+ ", Step 2",style='italic',loc='right')
    _,_,_ = ax[1].hist(theta0_G[theta0_G!=dummyval],
                     bins=bins,
                     label=r'($\mu$, $\sigma$) = {}'.format(theta0_param),
                     **plot_style_2)

    _,_,_ = ax[1].hist(
        theta0_G[theta0_G!=dummyval],
        bins=bins,
        label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),
        weights=weights[i, 1, :][theta0_G!=dummyval],
        **plot_style_1)
    _,_,_ = ax[1].hist(theta_unknown_G[theta_unknown_G!=dummyval],
                     bins=bins,
                     label=r'($\mu$, $\sigma$) = ?',
                     **plot_style_2,
                    color="green")
    ax[1].legend(frameon=False)
    ax[1].set_xlabel(r"$x_G$")
    ax[1].set_ylabel("Events per bin")
    
    plt.savefig("plot_"+str(i+1)+".pdf")
# Out:
# ITERATION 1:
# ITERATION 2:
# ITERATION 3:
# ITERATION 4:

# %% [markdown]
# ## Owen: inspecting a few things after running everything

# %%
weights
# Out:
# array([[[1.26053107, 0.76336598, 0.89225549, ..., 1.0212152 ,
#          1.19141912, 0.96722376],
#         [1.18959475, 0.9954226 , 1.0330255 , ..., 1.09620667,
#          0.99490488, 0.96059006]],
#
#        [[1.27955043, 0.91891277, 1.01029384, ..., 1.02007496,
#          1.03268766, 0.88504016],
#         [1.24237823, 0.97715312, 1.03343356, ..., 1.08776152,
#          0.90925986, 0.99735713]],
#
#        [[1.29243755, 0.96266788, 1.04236662, ..., 1.05853987,
#          0.91894567, 1.03635705],
#         [1.27351475, 0.9753049 , 1.0401485 , ..., 1.05197215,
#          0.83928132, 0.96292472]],
#
#        [[1.29726303, 0.98098052, 1.06163013, ..., 1.06495273,
#          0.85310006, 0.96269602],
#         [1.30482757, 0.9984479 , 1.06004035, ..., 1.06588483,
#          0.85680956, 1.02687788]]])

# %%
weights.shape
# Out:
# (4, 2, 100000)

# %%
Input
# Out:
# <function keras.engine.input_layer.Input(shape=None, batch_size=None, name=None, dtype=None, sparse=None, tensor=None, ragged=None, type_spec=None, **kwargs)>

# %%
Model
# Out:
# keras.engine.training.Model

# %%
x_data_and_MCback
# Out:
# array([-1.38787902,  1.58279173,  1.69621817, ...,  1.04051159,
#        -0.17419594,  2.61053289])

# %%
x_data_and_MCback.shape
# Out:
# (210298,)

# %%
y_data_and_MCback
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
y_data_and_MCback.shape
# Out:
# (210298,)

# %%
W_data_and_MCback
# Out:
# array([-1., -1., -1., ...,  1.,  1.,  1.])

# %%
W_data_and_MCback.shape
# Out:
# (210298,)

# %%
w_data
# Out:
# array([0.8690763 , 0.9209438 , 0.9061657 , ..., 0.9169385 , 0.9036878 ,
#        0.85787016], dtype=float32)

# %%
w_data.shape
# Out:
# (100149,)

# %%
theta_unknown_S_withback[theta_unknown_S_withback!=dummyval]
# Out:
# array([-1.04909161,  0.93310101, -0.26723738, ...,  1.04051159,
#        -0.17419594,  2.61053289])

# %%
theta_unknown_S_withback[theta_unknown_S_withback!=dummyval].shape
# Out:
# (100149,)

# %%
fig,ax = plt.subplots(1,1,figsize=(10,10))

ax.hist2d(theta_unknown_S_withback[theta_unknown_S_withback!=dummyval],
         w_data,
         density=True,
         bins=200,
         norm=mpl.colors.LogNorm())

plt.show()

# %%
fig,ax = plt.subplots(4,2,figsize=(20,40))

for i in range(0,4):
    
    ax[i][0].plot( of_training_history[i][0][of_training_history[i][0]>0] )
    ax[i][0].plot( of_training_history_val[i][0][of_training_history[i][0]>0] )
    
    ax[i][1].plot( of_training_history[i][1][of_training_history[i][1]>0] )
    ax[i][1].plot( of_training_history_val[i][1][of_training_history[i][1]>0] )    
    
plt.show()
